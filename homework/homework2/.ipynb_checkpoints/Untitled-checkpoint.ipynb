# %%
#"Environment & Config Check"

try:
    import numpy as np
    from dotenv import load_dotenv
    print("Imports OK")
except Exception as e:
    print("Import error:", e)
    raise
# Out:
# Imports OK

# %%
from pathlib import Path
load_dotenv()  # looks for a .env file in the current and parent directories
print(".env loaded (if present)")
# Out:
# .env loaded (if present)

# %%
# src/config.py (inline demo)
from typing import Optional

def get_key(name: str, default: Optional[str] = None) -> Optional[str]:
    return os.getenv(name, default)

PROJECT_ROOT = Path.cwd()
DATA_DIR = PROJECT_ROOT / "data"
print("PROJECT_ROOT:", PROJECT_ROOT)
print("DATA_DIR:", DATA_DIR)
# Out:
# PROJECT_ROOT: /Users/brandonalcaide/bootcamp_Brandon_Alcaide/homework/homework2
# DATA_DIR: /Users/brandonalcaide/bootcamp_Brandon_Alcaide/homework/homework2/data

# %%
arr = np.array([1, 2, 3, 4, 5])
print("Array:", arr)
print("Mean:", arr.mean())
print("Vectorized * 10:", arr * 10)
# Out:
# Array: [1 2 3 4 5]
# Mean: 3.0
# Vectorized * 10: [10 20 30 40 50]

# %%
pip freeze > requirements.txt
# Out:
# Note: you may need to restart the kernel to use updated packages.
