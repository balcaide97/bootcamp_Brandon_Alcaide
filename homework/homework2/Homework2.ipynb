# %%
import os, textwrap, pathlib
REPO_NAME = "Stage2_Tooling Set up"
FOLDERS = ["data", "src", "notebooks", "docs"]

base = pathlib.Path.cwd() / REPO_NAME
base.mkdir(exist_ok=True)
for f in FOLDERS:
    (base / f).mkdir(parents=True, exist_ok=True)
README_TEMPLATE = textwrap.dedent("")

readme_path = base / "README.md"
if not readme_path.exists():
    readme_path.write_text(README_TEMPLATE, encoding="utf-8")
readme_path.resolve()
# Out:
# PosixPath('/Users/brandonalcaide/bootcamp_Brandon_Alcaide/Stage2_Tooling Set up/README.md')

# %%
API_KEY=12345
DATA_DIR=1

# %%
from dotenv import load_dotenv
import os
load_dotenv()
api_key = os.getenv("API_KEY")
