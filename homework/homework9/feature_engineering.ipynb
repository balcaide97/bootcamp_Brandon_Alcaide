# %% [markdown]
# # Stage 09 — Homework Starter Notebook
#
# In the lecture, we learned how to create engineered features. Now it’s your turn to apply those ideas to your own project data.

# %%
import pandas as pd
import numpy as np

# Example synthetic data (replace with your project dataset)
np.random.seed(0)
n = 100
df = pd.DataFrame({
    'income': np.random.normal(60000, 15000, n).astype(int),
    'monthly_spend': np.random.normal(2000, 600, n).astype(int),
    'credit_score': np.random.normal(680, 50, n).astype(int)
})
df.head()
# Out:
#    income  monthly_spend  credit_score
# 0   86460           3129           661
# 1   66002           1191           668
# 2   74681           1237           734
# 3   93613           2581           712
# 4   88013           1296           712

# %% [markdown]
# ## TODO: Implement at least 2 engineered features here

# %%
df['spend_income_ratio'] = df['monthly_spend'] / df['income']

# %% [markdown]
# ### Rationale for Feature 1
# Explain why this feature may help a model. Reference your EDA.

# %%
This feature will take a step further on the spend to income information. Which helps to better undestand per dollar how individuals spend by portion of there income.
In general, the average monthly spend should be tied to your income, but in reality, lower incomes may overspend.

# %%
df['spending_credit_ratio'] = df['monthly_spend'] / df['credit_score']

# %% [markdown]
# ### Rationale for Feature 2
# Explain why this feature may help a model. Reference your EDA.

# %%
This additional feature will see how a person's credit score impact monthly spending. In general, a stronger credit implies better management of credit card 
This can better access the relationship between credit to total spending.
